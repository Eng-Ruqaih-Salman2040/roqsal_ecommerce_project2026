# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as pit 
import seaborn as sns 
# %matplotlib inline 
sns.set()

# %%
am=pd.read_csv('anemia.csv')

# %%
am.head()
# Out:
#    Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0       1        14.9  22.7  29.1  83.7       0
# 1       0        15.9  25.4  28.3  72.0       0
# 2       0         9.0  21.5  29.6  71.2       1
# 3       0        14.9  16.0  31.4  87.5       0
# 4       1        14.7  22.0  28.2  99.5       0

# %%
am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      1421 non-null   int64
#  1   Hemoglobin  1421 non-null   float64
#  2   MCH         1421 non-null   float64
#  3   MCHC        1421 non-null   float64
#  4   MCV         1421 non-null   float64
#  5   Result      1421 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 66.7 KB

# %%
am.describe().round(3)
# Out:
#          Gender  Hemoglobin       MCH      MCHC       MCV    Result
# count  1421.000    1421.000  1421.000  1421.000  1421.000  1421.000
# mean      0.521      13.413    22.906    30.251    85.524     0.436
# std       0.500       1.975     3.969     1.401     9.637     0.496
# min       0.000       6.600    16.000    27.800    69.400     0.000
# 25%       0.000      11.700    19.400    29.000    77.300     0.000
# 50%       1.000      13.200    22.700    30.400    85.300     0.000
# 75%       1.000      15.000    26.200    31.400    94.200     1.000
# max       1.000      16.900    30.000    32.500   101.600     1.000

# %%
am.plot(subplots=True,figsize=(20,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 am.plot(subplots=True,figsize=(20,10))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
am.columns
# Out:
# Index(['Gender', 'Hemoglobin', 'MCH', 'MCHC', 'MCV', 'Result'], dtype='object')

# %%
am.rename(columns={'Gender':'Gendere'},inplace=True)

# %%
am
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0           1        14.9  22.7  29.1  83.7       0
# 1           0        15.9  25.4  28.3  72.0       0
# 2           0         9.0  21.5  29.6  71.2       1
# 3           0        14.9  16.0  31.4  87.5       0
# 4           1        14.7  22.0  28.2  99.5       0
# ...       ...         ...   ...   ...   ...     ...
# 1416        0        10.6  25.4  28.2  82.9       1
# 1417        1        12.1  28.3  30.4  86.9       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %%
am['Result'].value_counts()
# Out:
# 0    801
# 1    620
# Name: Result, dtype: int64

# %%
am.Result.replace({'1':'0'},inplace=True)

# %%
am
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0           1        14.9  22.7  29.1  83.7       0
# 1           0        15.9  25.4  28.3  72.0       0
# 2           0         9.0  21.5  29.6  71.2       1
# 3           0        14.9  16.0  31.4  87.5       0
# 4           1        14.7  22.0  28.2  99.5       0
# ...       ...         ...   ...   ...   ...     ...
# 1416        0        10.6  25.4  28.2  82.9       1
# 1417        1        12.1  28.3  30.4  86.9       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %%
am.dtypes
# Out:
# Gendere         int64
# Hemoglobin    float64
# MCH           float64
# MCHC          float64
# MCV           float64
# Result          int64
# dtype: object

# %%
am.Hemoglobin
# Out:
# 0       14.9
# 1       15.9
# 2        9.0
# 3       14.9
# 4       14.7
#         ...
# 1416    10.6
# 1417    12.1
# 1418    13.1
# 1419    14.3
# 1420    11.8
# Name: Hemoglobin, Length: 1421, dtype: float64

# %%
am.Hemoglobin.value_counts()
# Out:
# 11.5    39
# 13.4    37
# 11.1    37
# 13.2    36
# 13.1    36
#         ..
# 9.1      1
# 7.8      1
# 8.6      1
# 7.5      1
# 9.9      1
# Name: Hemoglobin, Length: 81, dtype: int64

# %%
am.describe()
# Out:
#            Gendere   Hemoglobin          MCH         MCHC          MCV  \
# count  1421.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean      0.520760    13.412738    22.905630    30.251232    85.523786
# std       0.499745     1.974546     3.969375     1.400898     9.636701
# min       0.000000     6.600000    16.000000    27.800000    69.400000
# 25%       0.000000    11.700000    19.400000    29.000000    77.300000
# 50%       1.000000    13.200000    22.700000    30.400000    85.300000
# 75%       1.000000    15.000000    26.200000    31.400000    94.200000
# max       1.000000    16.900000    30.000000    32.500000   101.600000
#
#             Result
# count  1421.000000
# mean      0.436312
# std       0.496102
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
am.Hemoglobin.plot()
# Out:
# <Axes: >

# %%
am['Hemoglobin'].idxmin()
# Out:
# 349

# %%
am['Hemoglobin'].min()
# Out:
# 6.6

# %%
am['Hemoglobin'].describe()
# Out:
# count    1421.000000
# mean       13.412738
# std         1.974546
# min         6.600000
# 25%        11.700000
# 50%        13.200000
# 75%        15.000000
# max        16.900000
# Name: Hemoglobin, dtype: float64

# %%
am.isna().sum()
# Out:
# Gendere       0
# Hemoglobin    0
# MCH           0
# MCHC          0
# MCV           0
# Result        0
# dtype: int64

# %%
am.duplicated().any(axis=0)
# Out:
# True

# %%
am.loc[am.duplicated(subset=['Hemoglobin'])].sort_values('Hemoglobin')
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 421         1         9.0  23.0  30.5  69.8       1
# 493         0         9.2  19.3  31.4  78.9       1
# 596         1         9.6  23.0  30.3  87.7       1
# 664         0        10.0  29.8  32.0  92.1       1
# 328         0        10.3  27.0  32.4  71.6       1
# ...       ...         ...   ...   ...   ...     ...
# 589         1        16.9  24.2  32.1  92.5       0
# 527         0        16.9  25.5  29.6  83.2       0
# 136         0        16.9  16.7  30.0  78.4       0
# 352         1        16.9  24.2  32.1  92.5       0
# 1165        0        16.9  19.3  29.1  82.1       0
#
# [1340 rows x 6 columns]

# %%
am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gendere     1421 non-null   int64
#  1   Hemoglobin  1421 non-null   float64
#  2   MCH         1421 non-null   float64
#  3   MCHC        1421 non-null   float64
#  4   MCV         1421 non-null   float64
#  5   Result      1421 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 66.7 KB

# %%
am.notna()
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0        True        True  True  True  True    True
# 1        True        True  True  True  True    True
# 2        True        True  True  True  True    True
# 3        True        True  True  True  True    True
# 4        True        True  True  True  True    True
# ...       ...         ...   ...   ...   ...     ...
# 1416     True        True  True  True  True    True
# 1417     True        True  True  True  True    True
# 1418     True        True  True  True  True    True
# 1419     True        True  True  True  True    True
# 1420     True        True  True  True  True    True
#
# [1421 rows x 6 columns]

# %%
am.notna().sum()
# Out:
# Gendere       1421
# Hemoglobin    1421
# MCH           1421
# MCHC          1421
# MCV           1421
# Result        1421
# dtype: int64

# %%
am.isna().any()
# Out:
# Gendere       False
# Hemoglobin    False
# MCH           False
# MCHC          False
# MCV           False
# Result        False
# dtype: bool

# %%
am.head()
# Out:
#    Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0        1        14.9  22.7  29.1  83.7       0
# 1        0        15.9  25.4  28.3  72.0       0
# 2        0         9.0  21.5  29.6  71.2       1
# 3        0        14.9  16.0  31.4  87.5       0
# 4        1        14.7  22.0  28.2  99.5       0

# %%
am.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1416     True
# 1417     True
# 1418     True
# 1419     True
# 1420     True
# Length: 1421, dtype: bool

# %%
am[am.duplicated()]
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 237         1        14.9  22.7  29.1  83.7       0
# 238         0        15.9  25.4  28.3  72.0       0
# 240         0        14.9  16.0  31.4  87.5       0
# 242         0        11.6  22.3  30.9  74.5       1
# 243         1        12.7  19.5  28.9  82.9       1
# ...       ...         ...   ...   ...   ...     ...
# 1416        0        10.6  25.4  28.2  82.9       1
# 1417        1        12.1  28.3  30.4  86.9       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [887 rows x 6 columns]

# %%
am.drop(index=[1416,1417])
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0           1        14.9  22.7  29.1  83.7       0
# 1           0        15.9  25.4  28.3  72.0       0
# 2           0         9.0  21.5  29.6  71.2       1
# 3           0        14.9  16.0  31.4  87.5       0
# 4           1        14.7  22.0  28.2  99.5       0
# ...       ...         ...   ...   ...   ...     ...
# 1414        0        13.0  26.2  31.3  74.9       0
# 1415        1        13.2  20.1  28.8  91.2       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [1419 rows x 6 columns]

# %%
am.drop_duplicates(subset=['Gendere'])
# Out:
#    Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0        1        14.9  22.7  29.1  83.7       0
# 1        0        15.9  25.4  28.3  72.0       0

# %%
am.drop_duplicates(subset=['Gendere'],keep='last')
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 1418        1        13.1  17.7  28.1  80.7       1
# 1420        0        11.8  21.2  28.4  98.1       1

# %%
am
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0           1        14.9  22.7  29.1  83.7       0
# 1           0        15.9  25.4  28.3  72.0       0
# 2           0         9.0  21.5  29.6  71.2       1
# 3           0        14.9  16.0  31.4  87.5       0
# 4           1        14.7  22.0  28.2  99.5       0
# ...       ...         ...   ...   ...   ...     ...
# 1416        0        10.6  25.4  28.2  82.9       1
# 1417        1        12.1  28.3  30.4  86.9       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %%
am.plot(subplots=True,figsize=(40,20))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
am.describe()
# Out:
#            Gendere   Hemoglobin          MCH         MCHC          MCV  \
# count  1421.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean      0.520760    13.412738    22.905630    30.251232    85.523786
# std       0.499745     1.974546     3.969375     1.400898     9.636701
# min       0.000000     6.600000    16.000000    27.800000    69.400000
# 25%       0.000000    11.700000    19.400000    29.000000    77.300000
# 50%       1.000000    13.200000    22.700000    30.400000    85.300000
# 75%       1.000000    15.000000    26.200000    31.400000    94.200000
# max       1.000000    16.900000    30.000000    32.500000   101.600000
#
#             Result
# count  1421.000000
# mean      0.436312
# std       0.496102
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
am.describe().round()
# Out:
#        Gendere  Hemoglobin     MCH    MCHC     MCV  Result
# count   1421.0      1421.0  1421.0  1421.0  1421.0  1421.0
# mean       1.0        13.0    23.0    30.0    86.0     0.0
# std        0.0         2.0     4.0     1.0    10.0     0.0
# min        0.0         7.0    16.0    28.0    69.0     0.0
# 25%        0.0        12.0    19.0    29.0    77.0     0.0
# 50%        1.0        13.0    23.0    30.0    85.0     0.0
# 75%        1.0        15.0    26.0    31.0    94.0     1.0
# max        1.0        17.0    30.0    32.0   102.0     1.0

# %%
am.boxplot('Hemoglobin')
# Out:
# <Axes: >

# %%
am[am.Hemoglobin<16]
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0           1        14.9  22.7  29.1  83.7       0
# 1           0        15.9  25.4  28.3  72.0       0
# 2           0         9.0  21.5  29.6  71.2       1
# 3           0        14.9  16.0  31.4  87.5       0
# 4           1        14.7  22.0  28.2  99.5       0
# ...       ...         ...   ...   ...   ...     ...
# 1416        0        10.6  25.4  28.2  82.9       1
# 1417        1        12.1  28.3  30.4  86.9       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [1231 rows x 6 columns]

# %%
am_dups=am[am.Hemoglobin<16]

# %%
am_dups
# Out:
#       Gendere  Hemoglobin   MCH  MCHC   MCV  Result
# 0           1        14.9  22.7  29.1  83.7       0
# 1           0        15.9  25.4  28.3  72.0       0
# 2           0         9.0  21.5  29.6  71.2       1
# 3           0        14.9  16.0  31.4  87.5       0
# 4           1        14.7  22.0  28.2  99.5       0
# ...       ...         ...   ...   ...   ...     ...
# 1416        0        10.6  25.4  28.2  82.9       1
# 1417        1        12.1  28.3  30.4  86.9       1
# 1418        1        13.1  17.7  28.1  80.7       1
# 1419        0        14.3  16.2  29.5  95.2       0
# 1420        0        11.8  21.2  28.4  98.1       1
#
# [1231 rows x 6 columns]
