# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
b = pd.read_csv('flixpatrol.csv')

# %%
b
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime in Million
# 0         Action  812,100,000               812.1M
# ...

# %%
b.plot(subplots = True,figsize=(30,10))
plt.show()

# %%
b.columns
# Out:
# Index(['Rank', 'Title', 'Type', 'Premiere', 'Genre', 'Watchtime',
#        'Watchtime in Million'],
#       dtype='object')

# %%
b.describe().round(2)
# Out:
#            Rank  Premiere
# count  18164.00  18030.00
# mean    9126.72   2014.19
# std     5252.51      8.84
# min        1.00   1940.00
# 25%     4591.75   2012.00
# 50%     9132.50   2017.00
# 75%    13673.25   2020.00
# max    18214.00   2023.00

# %%
b.head()
# Out:
#    Rank                                Title     Type  Premiere     Genre  \
# 0   1.0                      The Night Agent  TV Show    2023.0    Action
# 1   2.0                      Ginny & Georgia  TV Show    2021.0     Drama
# 2   3.0                            The Glory  TV Show    2022.0  Thriller
# 3   4.0                            Wednesday  TV Show    2022.0   Fantasy
# 4   5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0     Drama
#
#      Watchtime Watchtime in Million
# 0  812,100,000               812.1M
# 1  665,100,000               665.1M
# 2  622,800,000               622.8M
# 3  507,700,000               507.7M
# 4  503,000,000               503.0M

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18164 entries, 0 to 18163
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  18164 non-null  float64
#  1   Title                 18164 non-null  object
#  2   Type                  18164 non-null  object
#  3   Premiere              18030 non-null  float64
#  4   Genre                 17984 non-null  object
#  5   Watchtime             18164 non-null  object
#  6   Watchtime in Million  18164 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 993.5+ KB

# %%
b.rename(columns={'Watchtime in Million':'Watchtime_in_Million'},inplace= True)

# %%
b
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime_in_Million
# 0         Action  812,100,000               812.1M
# ...

# %%
b['Type'].value_counts()
# Out:
# Movie      10880
# TV Show     7284
# Name: Type, dtype: int64

# %%
b['Genre'].value_counts()
# Out:
# Comedy             3946
# Drama              3349
# Animation          2670
# Documentary        1294
# Action             1100
# Crime              1081
# Thriller            675
# Horror              654
# Reality-Show        574
# Romance             519
# Science Fiction     398
# Fantasy             303
# Adventure           281
# Stand-Up            224
# Biography           199
# History             154
# Superhero           143
# War                  90
# Talk Show            82
# Family               72
# Western              55
# Musical              40
# Broadcast            22
# Concerts             20
# Sports               17
# Fairy Tale           12
# Game-Show             9
# News                  1
# Name: Genre, dtype: int64

# %%
b.Genre.replace("News","Game-Show",inplace=True)

# %%
b['Genre'].value_counts()
# Out:
# Comedy             3946
# Drama              3349
# Animation          2670
# Documentary        1294
# Action             1100
# Crime              1081
# Thriller            675
# Horror              654
# Reality-Show        574
# Romance             519
# Science Fiction     398
# Fantasy             303
# Adventure           281
# Stand-Up            224
# Biography           199
# History             154
# Superhero           143
# War                  90
# Talk Show            82
# Family               72
# Western              55
# Musical              40
# Broadcast            22
# Concerts             20
# Sports               17
# Fairy Tale           12
# Game-Show            10
# Name: Genre, dtype: int64

# %%
b['Watchtime_in_Million'].value_counts()
# Out:
# 0.1M      3811
# 0.2M      1890
# 0.3M      1151
# 0.4M       823
# 0.5M       661
#           ...
# 56.6M        1
# 56.3M        1
# 56.0M        1
# 55.7M        1
# 812.1M       1
# Name: Watchtime_in_Million, Length: 710, dtype: int64

# %%
b['Watchtime_in_Million']
# Out:
# 0        812.1M
# 1        665.1M
# 2        622.8M
# 3        507.7M
# 4        503.0M
#           ...
# 18159      0.1M
# 18160      0.1M
# 18161      0.1M
# 18162      0.1M
# 18163      0.1M
# Name: Watchtime_in_Million, Length: 18164, dtype: object

# %%
b['Watchtime_in_Million']=b['Watchtime_in_Million'].str.replace("M","")

# %%
b
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime_in_Million
# 0         Action  812,100,000                812.1
# ...

# %%
b.Title=b.Title.str.lower().str.strip()
#تحويل اللا اسمول وحذف المسافات

# %%
b
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      the night agent  TV Show    2023.0
# 1          2.0                      ginny & georgia  TV Show    2021.0
# 2          3.0                            the glory  TV Show    2022.0
# 3          4.0                            wednesday  TV Show    2022.0
# 4          5.0  queen charlotte: a bridgerton story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      spiritual house  TV Show    2017.0
# 18160  18211.0                      suite francaise    Movie    2014.0
# 18161  18212.0                 the bishop's bedroom    Movie    1977.0
# 18162  18213.0                     30 chưa phải tết    Movie    2020.0
# 18163  18214.0                    the promised land    Movie    2019.0
#
#            Genre    Watchtime Watchtime_in_Million
# 0         Action  812,100,000                812.1
# ...

# %%
b.Watchtime_in_Million=b.Watchtime_in_Million.astype('float')

# %%
b.dtypes
# Out:
# Rank                    float64
# Title                    object
# Type                     object
# Premiere                float64
# Genre                    object
# Watchtime                object
# Watchtime_in_Million    float64
# dtype: object

# %%
b.Watchtime_in_Million.value_counts()
# Out:
# 0.1      3811
# 0.2      1890
# 0.3      1151
# 0.4       823
# 0.5       661
#          ...
# 56.6        1
# 56.3        1
# 56.0        1
# 55.7        1
# 812.1       1
# Name: Watchtime_in_Million, Length: 710, dtype: int64

# %%
b.isna()
# Out:
#         Rank  Title   Type  Premiere  Genre  Watchtime  Watchtime_in_Million
# 0      False  False  False     False  False      False                 False
# 1      False  False  False     False  False      False                 False
# 2      False  False  False     False  False      False                 False
# 3      False  False  False     False  False      False                 False
# 4      False  False  False     False  False      False                 False
# ...      ...    ...    ...       ...    ...        ...                   ...
# 18159  False  False  False     False  False      False                 False
# 18160  False  False  False     False  False      False                 False
# 18161  False  False  False     False  False      False                 False
# 18162  False  False  False     False  False      False                 False
# 18163  False  False  False     False  False      False                 False
#
# [18164 rows x 7 columns]

# %%
b.isna().sum()
# Out:
# Rank                      0
# Title                     0
# Type                      0
# Premiere                134
# Genre                   180
# Watchtime                 0
# Watchtime_in_Million      0
# dtype: int64

# %%
b[b.isna()]
# Out:
#        Rank Title Type  Premiere Genre Watchtime  Watchtime_in_Million
# 0       NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 1       NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 2       NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 3       NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 4       NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# ...     ...   ...  ...       ...   ...       ...                   ...
# 18159   NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 18160   NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 18161   NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 18162   NaN   NaN  NaN       NaN   NaN       NaN                   NaN
# 18163   NaN   NaN  NaN       NaN   NaN       NaN                   NaN
#
# [18164 rows x 7 columns]

# %%
b[b.isna().values]
# Out:
#           Rank                                           Title     Type  \
# 188      189.0                                        bebefinn  TV Show
# 591      592.0                      pokémon: ultimate journeys  TV Show
# 983      984.0                      pokémon: ultimate journeys  TV Show
# 1580    1581.0                               gecko's garage 3d  TV Show
# 2931    2982.0                      pokémon: ultimate journeys  TV Show
# ...        ...                                             ...      ...
# 18074  18125.0  feather & flowers the original returns concert    Movie
# 18078  18129.0                 rudra: secret of the black moon    Movie
# 18083  18134.0                                        beyblade  TV Show
# 18094  18145.0                 rudra: the rise of king pharaoh    Movie
# 18151  18202.0                               feel-good fitness  TV Show
#
#        Premiere      Genre   Watchtime  Watchtime_in_Million
# ...

# %%
b.isna().any()
# Out:
# Rank                    False
# Title                   False
# Type                    False
# Premiere                 True
# Genre                    True
# Watchtime               False
# Watchtime_in_Million    False
# dtype: bool

# %%
b['Genre'].isna().sum()
# Out:
# 180

# %%
b['Premiere'].isna().sum()
# Out:
# 134

# %%
b.dropna()
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime in Million
# 0         Action  812,100,000               812.1M
# ...

# %%
b_without_dups=b[(b.Rank<9000)&(b.Rank>2)]

# %%
b_without_dups
# Out:
#         Rank                                Title     Type  Premiere  \
# 2        3.0                            The Glory  TV Show    2022.0
# 3        4.0                            Wednesday  TV Show    2022.0
# 4        5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# 5        6.0                                  You  TV Show    2018.0
# 6        7.0                     La Reina del Sur  TV Show    2011.0
# ...      ...                                  ...      ...       ...
# 8944  8995.0                        My SL Partner  TV Show       NaN
# 8945  8996.0                 The Door into Summer    Movie    2021.0
# 8946  8997.0                    My Wonderful Life    Movie    2021.0
# 8947  8998.0                         The Drowning  TV Show    2021.0
# 8948  8999.0                                Drift    Movie    2013.0
#
#                 Genre    Watchtime Watchtime in Million
# 2            Thriller  622,800,000               622.8M
# ...

# %%
b.to_csv('flixpatrol_clenaned.csv')
